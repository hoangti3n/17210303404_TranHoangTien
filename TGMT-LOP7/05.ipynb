# %%
# import thu vien
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/trant/Pictures/RS/1.png'

# %%
# ĐỌC ẢNH
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1000x500>

# %%
# Xoay ảnh
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=P size=1000x500>

# %%
# Xoay ảnh
rotated_image_rotate = rotated_image.rotate(90)
display(rotated_image_rotate)
# Out:
# <PIL.Image.Image image mode=P size=1000x500>

# %%
# Transpose ảnh
transpose_imgae = img.transpose(Image.Transpose.ROTATE_90)
display(transpose_imgae)
# Out:
# <PIL.Image.Image image mode=P size=500x1000>

# %%
# Transpose ảnh
transpose_imgae = transpose_imgae.transpose(Image.Transpose.ROTATE_90)
display(transpose_imgae)
# Out:
# <PIL.Image.Image image mode=P size=1000x500>
