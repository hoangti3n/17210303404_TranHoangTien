# %%
# import thu vien
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/trant/Pictures/RS/1.png'

# %%
# DOC ANH
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1000x500>

# %%
#DINH VI CHO CAT
region = (5, 100, 200, 425)
# CẮT ẢNH
cropped_img = img.crop(region)
display(cropped_img)
# Out:
# <PIL.Image.Image image mode=P size=195x325>

# %%
# Dán ảnh
paste_position = (300, 400)
img.paste(cropped_img, paste_position)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1000x500>
