# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
my_path = 'C:/Users/trant/Pictures/RS/02.png'

# %%
# ĐỌC ẢNH
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=660x659>

# %%
# Chuyển từ ảnh RGB sang ảnh xám
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=660x659>

# %%
# Phân RGB thành 3 tầng màu khác nhau
# red_band, green_band, blue_band = img.split()
red_band = img.split()
green_band = img.split()
blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# (<PIL.Image.Image image mode=L size=660x659>,
#  <PIL.Image.Image image mode=L size=660x659>,
#  <PIL.Image.Image image mode=L size=660x659>,
#  <PIL.Image.Image image mode=L size=660x659>)
# (<PIL.Image.Image image mode=L size=660x659>,
#  <PIL.Image.Image image mode=L size=660x659>,
#  <PIL.Image.Image image mode=L size=660x659>,
#  <PIL.Image.Image image mode=L size=660x659>)
# (<PIL.Image.Image image mode=L size=660x659>,
#  <PIL.Image.Image image mode=L size=660x659>,
#  <PIL.Image.Image image mode=L size=660x659>,
#  <PIL.Image.Image image mode=L size=660x659>)

# %%
# Trộn ảnh
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[133], line 2
#       1 # Trộn ảnh
# ----> 2 merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
#       3 display(merged_image)
#
# File D:\ANACONDA\Lib\site-packages\PIL\Image.py:3433, in merge(mode, bands)
#    3431     raise ValueError(msg)
#    3432 for band in bands[1:]:
# -> 3433     if band.mode != getmodetype(mode):
#    3434         msg = "mode mismatch"
#    3435         raise ValueError(msg)
#
# AttributeError: 'tuple' object has no attribute 'mode'
