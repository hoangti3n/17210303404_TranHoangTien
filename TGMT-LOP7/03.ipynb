# %%
# import thu vien
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
my_path = 'C:/Users/trant/Pictures/RS/1.png'

# %%
# DOC ANH
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1000x500>

# %%
# Thay đổi kích thước
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=1000x1000>

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
img_new_size = 'C:/Users/trant/Pictures/RS/new_img01.png'
img.save(img_new_size)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=50x25>
